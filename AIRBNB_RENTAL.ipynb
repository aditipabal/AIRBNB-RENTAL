# %%
# !pip install pysal h3
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 20.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.1/157.1 kB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.2/882.2 kB 44.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.9/47.9 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 67.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.6/141.6 kB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 3.2 MB/s eta 0:00:00
# ...

# %%
# Local Airbnb Point Interpolation (matches class notebook)
# Uses uploaded files: listings.csv + GISDATA.TOWNSSURVEY_POLYM.zip
# Predicts nightly price for a 2-bedroom "Entire rental unit" in Boston

import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
from sklearn.neighbors import RadiusNeighborsRegressor, NearestNeighbors
import tobler


linkBostonBorder="https://github.com/aditipabal/AIRBNB-RENTAL/blob/main/GISDATA.TOWNSSURVEY_POLYM.zip"
boston=gpd.read_file(linkBostonBorder)

linkBostonAIrbnb="https://github.com/aditipabal/AIRBNB-RENTAL/blob/main/listings.csv"
airbnb_all=pd.read_csv(linkBostonAIrbnb)
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# /tmp/ipython-input-974177132.py in <cell line: 0>()
#      12
#      13 linkBostonBorder="https://github.com/aditipabal/AIRBNB-RENTAL/blob/main/GISDATA.TOWNSSURVEY_POLYM.zip"
# ---> 14 boston=gpd.read_file(linkBostonBorder)
#      15
#      16 linkBostonAIrbnb="https://github.com/aditipabal/AIRBNB-RENTAL/blob/main/listings.csv"
#
# /usr/local/lib/python3.12/dist-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     314
#     315     if engine == "pyogrio":
# --> 316         return _read_file_pyogrio(
#     317             filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     318         )
#
# /usr/local/lib/python3.12/dist-packages/geopandas/io/file.py in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
# ...
